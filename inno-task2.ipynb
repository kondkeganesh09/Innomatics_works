# %%
sentence = input("Enter sentence: ")

words = sentence.split()
unique_words = set(words)

print("Unique words count:", len(unique_words))
print("Unique words:", unique_words)
# Out:
# Enter sentence:  Nice set of practice problems, Ganesh — these are perfect for logic building + Python basics 💪 I’ll give you simple, clean Python solutions for all 10 problems so you can understand and submit them
# Unique words count: 32
# Unique words: {'perfect', 'are', 'Python', 'simple,', '💪', 'them', 'logic', 'give', 'I’ll', 'and', 'for', '10', 'problems', 'you', 'set', '+', 'all', '—', 'of', 'problems,', 'building', 'Ganesh', 'practice', 'basics', 'solutions', 'submit', 'Nice', 'so', 'these', 'can', 'understand', 'clean'}

# %%
employees = {
    "Ravi": 75000,
    "Anita": 68000,
    "Kiran": 72000
}

highest_employee = max(employees, key=employees.get)
highest_salary = employees[highest_employee]

print("Highest Salary:", highest_employee, "-", highest_salary)
# Out:
# Highest Salary: Ravi - 75000

# %%
numbers = [45, 22, 89, 10, 66]

max_value = numbers[0]
min_value = numbers[0]

for num in numbers:
    if num > max_value:
        max_value = num
    if num < min_value:
        min_value = num

print("List:", numbers)
print("Max:", max_value)
print("Min:", min_value)
# Out:
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %%
prices = [450, 1200, 899, 1500, 300]

count = 0
for price in prices:
    if price > 500:
        print(price)
        count += 1

print("Products above 1000:", count)
# Out:
# 1200
# 899
# 1500
# Products above 1000: 3

# %%
attendance = ["P", "P", "A", "P", "P"]

present_count = attendance.count("P")
total_days = len(attendance)

percentage = (present_count / total_days) * 100

print("Attendance Percentage:", percentage)
# Out:
# Attendance Percentage: 80.0

# %%
phone_numbers = [9876543210, 9123456789, 9876543210,9123456789]

unique_numbers = set(phone_numbers)

print("Unique phone numbers:", unique_numbers)
# Out:
# Unique phone numbers: {9876543210, 9123456789}

# %%
string = "pythonp"
char_count = {}

for char in string:
    if char in char_count:
        char_count[char] += 1
    else:
        char_count[char] = 1

print(char_count)
# Out:
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %%
lst = [10, 20, 30]

tup = tuple(lst)

print("Tuple:", tup)
# Out:
# Tuple: (10, 20, 30)
